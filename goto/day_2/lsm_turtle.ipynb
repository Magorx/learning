# %%
import numpy as np

import turtle

# %% [markdown]
# # Интерактивная демонстрация линейной регрессии, переобучения, полиномиальных и тригонометрических признаков

# %% [markdown]
# ## Ставим точки, пускаем через них кривую

# %%
def one_term(x, t):  # здесь задаём вид аппроксимации
    if t % 2:
        return np.sin(2 * 3.14 * t * x)
    else:
         return np.cos(2 * 3.14 * t * x)

# %%
def one_row(x, n_terms):  # размножаем вширь до ширины n_terms
    return np.array([one_term(x, t) for t in range(n_terms)])

# %%
def create_lsm_matrix(a, n):  # lsm - least squares method
    xy = np.array(a)
    x = xy[:, 0].reshape(-1, 1)
    y = xy[:, 1].reshape(-1, 1)
    return np.concatenate(one_row(x, n), axis=0 if n == 1 else 1), y

# %%
def draw_points(a):
    turtle.up()
    turtle.clear()
    
    for point in a:
        turtle.pencolor((0, 0, 0))
        real_point = tuple(t*100 for t in point)
        turtle.goto(*real_point)  # переходим в точку, в которую раньше кликнули
        turtle.dot()  # ставим отметку


def draw_approximation(a):  # a - массив пар (x, y)
    n_terms = len(a) # количество слагаемых полинома (степень = deg - 1 !!!). Чем больше, тем легче переобучиться
    print(a)
    b, y = create_lsm_matrix(a, n_terms)  

    btb = b.T.dot(b)
    coef = 10**-10
    ones_matrix = np.eye(btb.shape[0], btb.shape[1]) * coef
    btb += ones_matrix
    print ('deg = ', n_terms - 1, ' npoints =', len(a), 'det =', np.linalg.det(btb))
    poly = np.linalg.inv(btb).dot(b.T.dot(y))

    minx = min(t[0] for t in a) - 1
    maxx = max(t[0] for t in a) + 1
    d = maxx - minx

    turtle.color((0, 1, 0))
    for sx in range(int(100*(minx - d/2)), int(100*(maxx + d/2))):  # sx - screen x, в 100 раз больше
        x = (float(sx)/100)
        y = one_row(x, n_terms).dot(poly)[0]
        approx_point = (sx, y*100)
        turtle.goto(*approx_point)
        turtle.down()

        
class MyPoints(object):
    def __init__(self):
        self.dat = []
    def my_click(self,x,y):
        self.dat.append((x/100,y/100))
        draw_points(self.dat)
        if len(self.dat) > 1:
            draw_approximation(self.dat)

# %%
points = MyPoints()  # здесь хранятся точки

turtle.getscreen().onclick(points.my_click)  # если кликнули, добавить ещё одну точку
turtle.tracer(0)  # не тратить время на анимацию
turtle.listen()
turtle.mainloop()  # появляется окно, куда можно кликать. Если выполнилось с ошибкой, исполнить ячейку ещё раз
# Out:
# [(-2.05, 1.89), (-0.68, 1.71)]
# deg =  1  npoints = 2 det = 1.45613177972721
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08)]
# deg =  2  npoints = 3 det = 6.877983372408094
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22)]
# deg =  3  npoints = 4 det = 23.313651082076515
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21)]
# deg =  4  npoints = 5 det = 20.20434130476934
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41)]
# deg =  5  npoints = 6 det = 6.806654496995616
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49)]
# deg =  6  npoints = 7 det = 147.31624464116814
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33)]
# deg =  7  npoints = 8 det = 12.430287728527171
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46)]
# deg =  8  npoints = 9 det = 3.6142514054241333
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21)]
# deg =  9  npoints = 10 det = 9.287413058708578e-09
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36)]
# deg =  10  npoints = 11 det = 5.430238689697488e-12
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24)]
# deg =  11  npoints = 12 det = 5.445538103166368e-10
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71)]
# deg =  12  npoints = 13 det = 1.755161030657042e-09
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66)]
# deg =  13  npoints = 14 det = 6.991596923322276e-16
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5)]
# deg =  14  npoints = 15 det = 1.5044797343963417e-18
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13)]
# deg =  15  npoints = 16 det = 3.949338888716355e-19
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2)]
# deg =  16  npoints = 17 det = 3.7471144495045734e-20
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48)]
# deg =  17  npoints = 18 det = 2.365783842562831e-18
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65)]
# deg =  18  npoints = 19 det = 5.682989618921414e-19
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69)]
# deg =  19  npoints = 20 det = 3.110693001288518e-18
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95)]
# deg =  20  npoints = 21 det = 1.5512601353447138e-22
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95)]
# deg =  21  npoints = 22 det = 4.0028309860493825e-20
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95)]
# deg =  22  npoints = 23 det = 1.3858520670056594e-16
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22)]
# deg =  23  npoints = 24 det = 1.3819644427132264e-15
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47)]
# deg =  24  npoints = 25 det = 5.102297514607841e-22
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67)]
# deg =  25  npoints = 26 det = 1.2569805679650984e-17
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68)]
# deg =  26  npoints = 27 det = 4.141064480440248e-18
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18)]
# deg =  27  npoints = 28 det = 1.967535835866392e-23
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04)]
# deg =  28  npoints = 29 det = 1.0652220866358067e-22
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55)]
# deg =  29  npoints = 30 det = 9.98028781247482e-23
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55), (1.99, 1.04)]
# deg =  30  npoints = 31 det = 1.8125326834325426e-21
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55), (1.99, 1.04), (-2.16, 1.73)]
# deg =  31  npoints = 32 det = 1.641027164279625e-17
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55), (1.99, 1.04), (-2.16, 1.73), (-2.5, 1.68)]
# deg =  32  npoints = 33 det = 1.3886544360650704e-19
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55), (1.99, 1.04), (-2.16, 1.73), (-2.5, 1.68), (-2.68, 1.72)]
# deg =  33  npoints = 34 det = 1.00022520037888e-24
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55), (1.99, 1.04), (-2.16, 1.73), (-2.5, 1.68), (-2.68, 1.72), (-2.74, 1.72)]
# deg =  34  npoints = 35 det = 2.55312986881789e-22
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55), (1.99, 1.04), (-2.16, 1.73), (-2.5, 1.68), (-2.68, 1.72), (-2.74, 1.72), (-2.8, 1.72)]
# deg =  35  npoints = 36 det = 3.4696963894692152e-25
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55), (1.99, 1.04), (-2.16, 1.73), (-2.5, 1.68), (-2.68, 1.72), (-2.74, 1.72), (-2.8, 1.72), (-2.82, 1.73)]
# deg =  36  npoints = 37 det = 1.3340813359184685e-30
# [(-2.05, 1.89), (-0.68, 1.71), (0.68, -0.08), (3.08, -2.22), (-1.5, -2.21), (-1.84, -2.41), (-2.3, -2.49), (-2.93, -2.33), (-3.04, -1.46), (-3.04, -1.21), (-2.46, -0.36), (-2.22, -0.24), (-2.9, 0.71), (-3.46, 0.66), (-3.57, 0.5), (-3.67, 0.13), (-3.55, -0.2), (-3.19, -0.48), (-2.85, -0.65), (-2.69, -0.69), (-1.69, -0.95), (-1.43, -0.95), (-1.27, -0.95), (3.03, -2.22), (2.54, -0.47), (-0.77, 1.67), (-1.06, 1.68), (0.31, 2.18), (1.29, 2.04), (1.82, 1.55), (1.99, 1.04), (-2.16, 1.73), (-2.5, 1.68), (-2.68, 1.72), (-2.74, 1.72), (-2.8, 1.72), (-2.82, 1.73), (-2.82, 1.73)]
# deg =  37  npoints = 38 det = 3.465779957870609e-37

# %% [markdown]
# # Упражнения

# %% [markdown]
# ## Исподвыподверт с недопереобучением

# %% [markdown]
# * Для количеств слагаемых многочлена n_terms = 3, 6, 9 ставить точки и смотреть, как проходит аппроксимация
# * По отладочному выводу выдвинуть гипотезу о зависимости качества аппроксимации от количества точек, причине плохого качества аппроксимации
# * Когда аппроксимация в точности проходит через наши точки?
#
# ### Выводы:

# %% [markdown]
# Cool!

# %% [markdown]
# ## Регулярные занятия - залог успеха

# %% [markdown]
# Добавить регуляризацию с $\lambda = 10^{-10}, 10^{-5}, 10^{-3}, 10^{-1}, 1 $
# * повторить предыдущее упражнение
# * Как и что изменилось?
# * Какое значение $\lambda$ лучше всего? Почему?
# ### Выводы:

# %% [markdown]
# Cool!

# %% [markdown]
# ## Учёный малый, но педант
# ### Уже понятно, когда аппроксимация в точности проходит через точки. Хорошо ли это?
#
# * Изменить строчку n_terms так, чтобы аппроксимация всегда проходила через поставленные точки
# * Попробовать "на глаз" поставить много (> 10) точек на параболу. Похожа ли на параболу аппроксимация?
# * Сделать то же самое при трёх слагаемых
#
# ### Выводы:

# %% [markdown]
# ## Fourier's Fury

# %% [markdown]
# ### Заменить полиномиальные признаки на тригонометрические
#
# * Внести изменения в one_term
# * Учесть, что для полноты чувств неплохо ставить на чётные места косинусы, на нечётные - синусы
# * В одном месте в функцию one_term передаётся скалярное значение, в другом - вектор. Нужно чтобы работало и там и там. numpy рулит

# %% [markdown]
# ## Совсем факультатив

# %% [markdown]
# ### Пофиксить мерзкую ошибку
# * Ячейка с turtle.mainloop выдаёт ошибку из-за того что не вызывается метод закрытия окна при нажатии на крестик
# * нагуглить правильное завершение turtle.mainloop(), вставить корректный обработчик
